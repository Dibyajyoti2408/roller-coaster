# %%
import numpy as np
import pandas as pd

# %%
data_url = 'https://andybek.com/pandas-soccer'

# %%
players = pd.read_csv(data_url)

# %%
players.info(verbose=False,memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Columns: 17 entries, name to new_signing
# dtypes: float64(2), int64(10), object(5)
# memory usage: 190.7 KB

# %%
players.dtypes.value_counts()
# Out:
# int64      10
# object      5
# float64     2
# dtype: int64

# %% [markdown]
# players.head()

# %% [markdown]
# #what are the players that have a market value exceeding 40M?

# %%
players.market_value > 40
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
players[players.market_value > 40].shape
# Out:
# (13, 17)

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players.position.unique().size
# Out:
# 14

# %%
players.position.isin(['LB','CB','RB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 460    False
# 461     True
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players.position.isin(['LB','CB','RB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 460    False
# 461     True
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
players.loc[players.position.isin(['LB','CB','RB'])]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 4           912        6.0   0.70%         121       2      France
# 5          1675        6.0  13.70%         119       2       Spain
# 7           555        5.5   4.70%         115       2       Spain
# 8          1877        5.5   4.00%          90       2     Germany
# 17          552        5.0   0.10%          45       3      Brazil
# ..          ...        ...     ...         ...     ...         ...
# 455         380        5.0   1.30%          60       1     England
# 458         247        4.5   1.10%          45       2       Italy
# 459         698        5.0   2.70%          45       3   Argentina
# 461         199        4.5   0.20%          34       4    Congo DR
# 462         198        4.5   0.30%          29       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 4              0        4        1         1            0
# 5              0        2        1         1            0
# 7              0        4        1         1            0
# 8              0        3        1         1            1
# 17             0        3        1         1            0
# ..           ...      ...      ...       ...          ...
# 455            0        3       20         0            0
# 458            0        4       20         0            0
# 459            0        5       20         0            0
# 461            0        2       20         0            1
# 462            0        2       20         0            0
#
# [154 rows x 17 columns]

# %%
players.market_value.between(40,50,inclusive=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
players.loc[players.market_value.between(40,50,inclusive=True)]
# Out:
#                     name               club  age position  position_cat  \
# 1             Mesut Ozil            Arsenal   28       AM             1
# 31   Alexandre Lacazette            Arsenal   26       CF             1
# 97           Diego Costa            Chelsea   28       CF             1
# 102     Thibaut Courtois            Chelsea   25       GK             4
# 108       N%27Golo Kante            Chelsea   26       DM             2
# 218    Philippe Coutinho          Liverpool   25       AM             1
# 219           Sadio Mane          Liverpool   25       LW             1
# 246      Raheem Sterling    Manchester+City   22       LW             1
# 263       Bernardo Silva    Manchester+City   22       RW             1
# 264        Romelu Lukaku  Manchester+United   24       CF             1
# 265         David de Gea  Manchester+United   26       GK             4
# 380            Dele Alli          Tottenham   21       CM             2
# 382    Christian Eriksen          Tottenham   25       AM             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 1            50.0        4395        9.5   5.60%         167       2
# 31           40.0        1183       10.5  26.50%           0       2
# 97           50.0        4454       10.0   3.00%         196       2
# 102          40.0        1260        5.5  18.50%         141       2
# 108          50.0        4042        5.0  13.80%          83       2
# 218          45.0        2958        9.0  30.80%         171       3
# 219          40.0        3219        9.5   5.30%         156       4
# 246          45.0        2074        8.0   3.80%         149       1
# 263          40.0        1098        8.0   4.60%           0       2
# 264          50.0        3727       11.5  45.00%         221       2
# 265          40.0        2126        5.5  26.10%         136       2
# 380          45.0        4626        9.5  38.60%         225       1
# 382          40.0        1130        9.5  12.00%         218       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 1       Germany            0        4        1         1            0
# 31       France            1        3        1         1            0
# 97        Spain            0        4        5         1            0
# 102     Belgium            0        3        5         1            0
# 108      France            0        3        5         1            1
# 218      Brazil            0        3       10         1            0
# 219     Senegal            0        3       10         1            1
# 246     England            0        2       11         1            0
# 263    Portugal            1        2       11         1            0
# 264     Belgium            0        2       12         1            0
# 265       Spain            0        3       12         1            0
# 380     England            0        1       17         1            0
# 382     Denmark            0        3       17         1            0

# %%
players.age <= 25
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460     True
# 461     True
# 462     True
# 463     True
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
players.loc[players.age <= 25]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 5          1675        6.0  13.70%         119       2        Spain
# 8          1877        5.5   4.00%          90       2      Germany
# 9          1812        5.5   1.00%          89       4      Nigeria
# 10         1815        5.5   2.00%          85       2  Switzerland
# 11         1815        5.5   2.00%          85       2  Switzerland
# ..          ...        ...     ...         ...     ...          ...
# 456         286        4.5   0.30%          55       2        Spain
# 460         288        4.5   0.40%          38       2  Switzerland
# 461         199        4.5   0.20%          34       4     Congo DR
# 462         198        4.5   0.30%          29       1      England
# 463         412        4.5   5.90%          16       1      England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 8              0        3        1         1            1
# 9              0        1        1         1            0
# 10             0        2        1         1            0
# 11             0        2        1         1            0
# ..           ...      ...      ...       ...          ...
# 456            0        3       20         0            0
# 460            0        1       20         0            1
# 461            0        2       20         0            1
# 462            0        2       20         0            0
# 463            0        1       20         0            1
#
# [172 rows x 17 columns]

# %%
players.loc[players.age.le(25)]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 5          1675        6.0  13.70%         119       2        Spain
# 8          1877        5.5   4.00%          90       2      Germany
# 9          1812        5.5   1.00%          89       4      Nigeria
# 10         1815        5.5   2.00%          85       2  Switzerland
# 11         1815        5.5   2.00%          85       2  Switzerland
# ..          ...        ...     ...         ...     ...          ...
# 456         286        4.5   0.30%          55       2        Spain
# 460         288        4.5   0.40%          38       2  Switzerland
# 461         199        4.5   0.20%          34       4     Congo DR
# 462         198        4.5   0.30%          29       1      England
# 463         412        4.5   5.90%          16       1      England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 8              0        3        1         1            1
# 9              0        1        1         1            0
# 10             0        2        1         1            0
# 11             0        2        1         1            0
# ..           ...      ...      ...       ...          ...
# 456            0        3       20         0            0
# 460            0        1       20         0            1
# 461            0        2       20         0            1
# 462            0        2       20         0            0
# 463            0        1       20         0            1
#
# [172 rows x 17 columns]

# %%
players.age.le(25).equals(players.age <= 25)
# Out:
# True

# %%
True | False
# Out:
# True

# %%
 False |  False
# Out:
# False

# %%
 False | True
# Out:
# True

# %%
True | True
# Out:
# True

# %%
f = pd.Series(False)

# %%
f
# Out:
# 0    False
# dtype: bool

# %%
t = pd.Series(True)

# %%
t
# Out:
# 0    True
# dtype: bool

# %%
t & f
# Out:
# 0    False
# dtype: bool

# %%
t | f
# Out:
# 0    True
# dtype: bool

# %%
t = pd.Series([True if i%2==0 else False for i in range(10)])

# %%
t
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
f = pd.Series([False for i in range(10)])

# %%
f
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
t & f
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
f = pd.Series(data=[False,True,True], index=['c','b','a'])
t = pd.Series(data=[True,False,False], index=['a','b','c'])

# %%
f & t
# Out:
# a     True
# b    False
# c    False
# dtype: bool

# %%
players[
            (players.position == 'LB') & 
            (players.age <= 25) &
            (players.market_value.ge(10))
             ]
# Out:
#                name               club  age position  position_cat  \
# 29   Sead Kolasinac            Arsenal   24       LB             3
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
# 389      Ben Davies          Tottenham   24       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29           15.0         618        6.0   6.90%           0       2
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
# 389          12.0         396        5.5   1.80%          90       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29       Bosnia            1        2        1         1            0
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0
# 389       Wales            0        2       17         1            0

# %%
players[
            (players.position == 'LB') & 
            (players.age <= 25) &
            (players.market_value.ge(10)) &
            ~(players.club.isin(['Arsenal','Tottenham']))
             ]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %%
arsenal_player = players.club == 'Arsenal'

# %%
arsenal_player
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: club, Length: 465, dtype: bool

# %%
right_back = players.position == 'RB'

# %%
right_back
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
chelsea_and_GK = (players.club == 'Chelsea') & (players.position == 'GK')

# %%
chelsea_and_GK
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players.loc[arsenal_player & right_back | chelsea_and_GK]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 5     Hector Bellerin  Arsenal   22       RB             3          30.0
# 27     Carl Jenkinson  Arsenal   25       RB             3           5.0
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 109   Willy Caballero  Chelsea   35       GK             4           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5          1675        6.0  13.70%         119       2       Spain
# 27          561        4.5   0.40%           2       1     England
# 102        1260        5.5  18.50%         141       2     Belgium
# 109         542        5.0   0.20%          64       3   Argentina
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 27             0        3        1         1            0
# 102            0        3        5         1            0
# 109            0        6        5         1            0

# %%
#Skill challenge

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.nationality.unique()
# Out:
# array(['Chile', 'Germany', 'Czech Republic', 'England', 'France', 'Spain',
#        'Nigeria', 'Switzerland', 'Wales', 'Brazil', 'Egypt', 'Argentina',
#        'Colombia', 'Bosnia', 'Norway', 'Poland', 'Scotland', 'Congo DR',
#        'Ireland', 'Netherlands', 'Australia', "Cote d'Ivoire", 'Finland',
#        'Cameroon', 'Austria', 'Israel', 'Northern Ireland', 'Canada',
#        'Belgium', 'Iceland', 'Serbia', 'Portugal', 'Ghana', 'South Korea',
#        'Mali', 'Senegal', 'Curacao', 'Denmark', 'Slovenia',
#        'Trinidad and Tobago', 'Bermuda', 'Benin', 'Algeria', 'Jamaica',
#        'Japan', 'Tunisia', 'Croatia', 'Estonia', 'Ecuador', 'Armenia',
#        'Italy', 'Sweden', 'United States', 'Morocco', 'The Gambia',
#        'Kenya', 'Greece', 'Uruguay', 'Romania', 'Venezuela',
#        'New Zealand'], dtype=object)

# %%
Players_nat = players.nationality == 'England'

# %%
avg_market_value = np.mean(players.market_value)

# %%
high_market_value = players.market_value.gt(2*avg_market_value)

# %%
players.new_signing.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
page_view_or_new_signing = (players.page_views > 4000) | (players.new_signing == 1)

# %%
players.loc[Players_nat & high_market_value & page_view_or_new_signing]
# Out:
#             name             club  age position  position_cat  market_value  \
# 256  John Stones  Manchester+City   23       CB             3          35.0
# 380    Dele Alli        Tottenham   21       CM             2          45.0
# 381   Harry Kane        Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 256        1078        5.5   2.30%          59       1     England
# 380        4626        9.5  38.60%         225       1     England
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 256            0        2       11         1            1
# 380            0        1       17         1            0
# 381            0        2       17         1            0

# %%
chelsea_23under = (players.club == 'Chelsea') & (players.age.le(23))

# %%
chelsea_23under.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
players.loc[chelsea_23under,['position','market_value']]
# Out:
#     position  market_value
# 110       CF          25.0
# 111       CB          15.0
# 112       LB           7.0
# 115       DM          16.0

# %%
p_cols = players.columns.str.startswith('p')

# %%
players.loc[chelsea_23under,p_cols]
# Out:
#     position  position_cat  page_views
# 110       CF             1        1162
# 111       CB             3         723
# 112       LB             3         566
# 115       DM             2        1011

# %%
players.lookup([0,132],['name', 'market_value'])
# Out:
# array(['Alexis Sanchez', 6.0], dtype=object)

# %%
players.lookup([0,132],['market_value','name'])
# Out:
# array([65.0, 'Connor Wickham'], dtype=object)

# %%
names = ['Petr Cech','Mesut Ozil','Alexis Sanchez']

# %%
attributes = ['age','market_value','page_views']

# %%
players.set_index('name').lookup(names,attributes)
# Out:
# array([  35.,   50., 4329.])

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.sort_values(by='market_value',ascending = False)
# Out:
#                     name               club  age position  position_cat  \
# 96           Eden Hazard            Chelsea   26       LW             1
# 267           Paul Pogba  Manchester+United   24       CM             2
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 244      Kevin De Bruyne    Manchester+City   26       AM             1
# 245        Sergio Aguero    Manchester+City   29       CF             1
# ..                   ...                ...  ...      ...           ...
# 287  Joel Castro Pereira  Manchester+United   21       GK             4
# 113     Eduardo Carvalho            Chelsea   34       LW             1
# 30          Granit Xhaka            Arsenal   24      NaN             2
# 192         Steve Mounie       Huddersfield   22       CF             1
# 195    Kasper Schmeichel     Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 96          75.00        4220       10.5   2.30%         224       2
# 267         75.00        7435        8.0  19.50%         115       2
# 0           65.00        4329       12.0  17.10%         264       3
# 244         65.00        2252       10.0  17.50%         199       2
# 245         65.00        4046       11.5   9.70%         175       3
# ..            ...         ...        ...     ...         ...     ...
# 287          0.10         395        4.0   1.00%           6       2
# 113          0.05         467        5.0   0.10%           0       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 96       Belgium            0        3        5         1            0
# 267       France            0        2       12         1            1
# 0          Chile            0        4        1         1            0
# 244      Belgium            0        3       11         1            0
# 245    Argentina            0        4       11         1            0
# ..           ...          ...      ...      ...       ...          ...
# 287     Portugal            0        1       12         1            0
# 113     Portugal            0        6        5         1            1
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0
#
# [465 rows x 17 columns]

# %%
players.index
# Out:
# RangeIndex(start=0, stop=465, step=1)

# %%
players.set_index('name',inplace=True)

# %%
players.head()
# Out:
#                       club  age position  position_cat  market_value  \
# name
# Alexis Sanchez     Arsenal   28       LW             1          65.0
# Mesut Ozil         Arsenal   28       AM             1          50.0
# Petr Cech          Arsenal   35       GK             4           7.0
# Theo Walcott       Arsenal   28       RW             1          20.0
# Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#                    page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Alexis Sanchez           4329       12.0  17.10%         264       3
# Mesut Ozil               4395        9.5   5.60%         167       2
# Petr Cech                1529        5.5   5.90%         134       2
# Theo Walcott             2393        7.5   1.50%         122       1
# Laurent Koscielny         912        6.0   0.70%         121       2
#
#                       nationality  new_foreign  age_cat  club_id  big_club  \
# name
# Alexis Sanchez              Chile            0        4        1         1
# Mesut Ozil                Germany            0        4        1         1
# Petr Cech          Czech Republic            0        6        1         1
# Theo Walcott              England            0        4        1         1
# Laurent Koscielny          France            0        4        1         1
#
#                    new_signing
# name
# Alexis Sanchez               0
# Mesut Ozil                   0
# Petr Cech                    0
# Theo Walcott                 0
# Laurent Koscielny            0

# %%
players.index
# Out:
# Index(['Alexis Sanchez', 'Mesut Ozil', 'Petr Cech', 'Theo Walcott',
#        'Laurent Koscielny', 'Hector Bellerin', 'Olivier Giroud',
#        'Nacho Monreal', 'Shkodran Mustafi', 'Alex Iwobi',
#        ...
#        'Aaron Cresswell', 'Pedro Obiang', 'Sofiane Feghouli', 'Angelo Ogbonna',
#        'Pablo Zabaleta', 'Edimilson Fernandes', 'Arthur Masuaku', 'Sam Byram',
#        'Ashley Fletcher', 'Diafra Sakho'],
#       dtype='object', name='name', length=465)

# %%
players.sort_index().head(10)
# Out:
#                             club  age position  position_cat  market_value  \
# name
# Aaron Cresswell         West+Ham   27       LB             3          12.0
# Aaron Lennon             Everton   30       RW             1           5.0
# Aaron Mooy          Huddersfield   26       CM             2           5.0
# Aaron Ramsey             Arsenal   26       CM             2          35.0
# Abdoulaye Doucoure       Watford   24       CM             2           6.0
# Adam Federici        Bournemouth   32       GK             4           1.0
# Adam Lallana           Liverpool   29       AM             1          25.0
# Adam Smith           Bournemouth   26       RB             3           5.0
# Ademola Lookman          Everton   19       LW             1           5.0
# Adrian                  West+Ham   30       GK             4           8.0
#
#                     page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Aaron Cresswell            380        5.0   1.30%          60       1
# Aaron Lennon               504        5.5   0.20%          22       1
# Aaron Mooy                 588        5.5   2.50%           0       4
# Aaron Ramsey              1040        7.0   5.10%          56       1
# Abdoulaye Doucoure         124        5.0   0.00%          38       2
# Adam Federici              126        4.0   1.50%           8       4
# Adam Lallana              1808        7.5   6.40%         139       1
# Adam Smith                 200        5.0   0.90%         104       1
# Ademola Lookman           1387        5.5   0.30%          16       1
# Adrian                     266        4.5   0.80%          64       2
#
#                    nationality  new_foreign  age_cat  club_id  big_club  \
# name
# Aaron Cresswell        England            0        3       20         0
# Aaron Lennon           England            0        4        7         0
# Aaron Mooy           Australia            0        3        8         0
# Aaron Ramsey             Wales            0        3        1         1
# Abdoulaye Doucoure      France            0        2       18         0
# Adam Federici        Australia            0        5        2         0
# Adam Lallana           England            0        4       10         1
# Adam Smith             England            0        3        2         0
# Ademola Lookman        England            0        1        7         0
# Adrian                   Spain            0        4       20         0
#
#                     new_signing
# name
# Aaron Cresswell               0
# Aaron Lennon                  0
# Aaron Mooy                    0
# Aaron Ramsey                  0
# Abdoulaye Doucoure            0
# Adam Federici                 0
# Adam Lallana                  0
# Adam Smith                    0
# Ademola Lookman               0
# Adrian                        0

# %%
players.sort_index(axis=1)
# Out:
#                      age  age_cat  big_club      club  club_id  fpl_points  \
# name
# Alexis Sanchez        28        4         1   Arsenal        1         264
# Mesut Ozil            28        4         1   Arsenal        1         167
# Petr Cech             35        6         1   Arsenal        1         134
# Theo Walcott          28        4         1   Arsenal        1         122
# Laurent Koscielny     31        4         1   Arsenal        1         121
# ...                  ...      ...       ...       ...      ...         ...
# Edimilson Fernandes   21        1         0  West+Ham       20          38
# Arthur Masuaku        23        2         0  West+Ham       20          34
# Sam Byram             23        2         0  West+Ham       20          29
# Ashley Fletcher       21        1         0  West+Ham       20          16
# Diafra Sakho          27        3         0  West+Ham       20          12
#
#                     fpl_sel  fpl_value  market_value     nationality  \
# name
# Alexis Sanchez       17.10%       12.0          65.0           Chile
# Mesut Ozil            5.60%        9.5          50.0         Germany
# Petr Cech             5.90%        5.5           7.0  Czech Republic
# Theo Walcott          1.50%        7.5          20.0         England
# Laurent Koscielny     0.70%        6.0          22.0          France
# ...                     ...        ...           ...             ...
# Edimilson Fernandes   0.40%        4.5           5.0     Switzerland
# Arthur Masuaku        0.20%        4.5           7.0        Congo DR
# Sam Byram             0.30%        4.5           4.5         England
# Ashley Fletcher       5.90%        4.5           1.0         England
# Diafra Sakho          0.10%        5.5          10.0         Senegal
#
#                      new_foreign  new_signing  page_views position  \
# name
# Alexis Sanchez                 0            0        4329       LW
# Mesut Ozil                     0            0        4395       AM
# Petr Cech                      0            0        1529       GK
# Theo Walcott                   0            0        2393       RW
# Laurent Koscielny              0            0         912       CB
# ...                          ...          ...         ...      ...
# Edimilson Fernandes            0            1         288       CM
# Arthur Masuaku                 0            1         199       LB
# Sam Byram                      0            0         198       RB
# Ashley Fletcher                0            1         412       CF
# Diafra Sakho                   0            0         214       CF
#
#                      position_cat  region
# name
# Alexis Sanchez                  1       3
# Mesut Ozil                      1       2
# Petr Cech                       4       2
# Theo Walcott                    1       1
# Laurent Koscielny               3       2
# ...                           ...     ...
# Edimilson Fernandes             2       2
# Arthur Masuaku                  3       4
# Sam Byram                       3       1
# Ashley Fletcher                 1       1
# Diafra Sakho                    1       4
#
# [465 rows x 16 columns]

# %%
players.reset_index().reset_index().reset_index()
# Out:
#      level_0  index                 name      club  age position  \
# 0          0      0       Alexis Sanchez   Arsenal   28       LW
# 1          1      1           Mesut Ozil   Arsenal   28       AM
# 2          2      2            Petr Cech   Arsenal   35       GK
# 3          3      3         Theo Walcott   Arsenal   28       RW
# 4          4      4    Laurent Koscielny   Arsenal   31       CB
# ..       ...    ...                  ...       ...  ...      ...
# 460      460    460  Edimilson Fernandes  West+Ham   21       CM
# 461      461    461       Arthur Masuaku  West+Ham   23       LB
# 462      462    462            Sam Byram  West+Ham   23       RB
# 463      463    463      Ashley Fletcher  West+Ham   21       CF
# 464      464    464         Diafra Sakho  West+Ham   27       CF
#
#      position_cat  market_value  page_views  fpl_value fpl_sel  fpl_points  \
# 0               1          65.0        4329       12.0  17.10%         264
# 1               1          50.0        4395        9.5   5.60%         167
# 2               4           7.0        1529        5.5   5.90%         134
# 3               1          20.0        2393        7.5   1.50%         122
# 4               3          22.0         912        6.0   0.70%         121
# ..            ...           ...         ...        ...     ...         ...
# 460             2           5.0         288        4.5   0.40%          38
# 461             3           7.0         199        4.5   0.20%          34
# 462             3           4.5         198        4.5   0.30%          29
# 463             1           1.0         412        4.5   5.90%          16
# 464             1          10.0         214        5.5   0.10%          12
#
#      region     nationality  new_foreign  age_cat  club_id  big_club  \
# 0         3           Chile            0        4        1         1
# 1         2         Germany            0        4        1         1
# 2         2  Czech Republic            0        6        1         1
# 3         1         England            0        4        1         1
# 4         2          France            0        4        1         1
# ..      ...             ...          ...      ...      ...       ...
# 460       2     Switzerland            0        1       20         0
# 461       4        Congo DR            0        2       20         0
# 462       1         England            0        2       20         0
# 463       1         England            0        1       20         0
# 464       4         Senegal            0        3       20         0
#
#      new_signing
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 460            1
# 461            1
# 462            0
# 463            1
# 464            0
#
# [465 rows x 19 columns]

# %%
players.head()
# Out:
#                       club  age position  position_cat  market_value  \
# name
# Alexis Sanchez     Arsenal   28       LW             1          65.0
# Mesut Ozil         Arsenal   28       AM             1          50.0
# Petr Cech          Arsenal   35       GK             4           7.0
# Theo Walcott       Arsenal   28       RW             1          20.0
# Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#                    page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Alexis Sanchez           4329       12.0  17.10%         264       3
# Mesut Ozil               4395        9.5   5.60%         167       2
# Petr Cech                1529        5.5   5.90%         134       2
# Theo Walcott             2393        7.5   1.50%         122       1
# Laurent Koscielny         912        6.0   0.70%         121       2
#
#                       nationality  new_foreign  age_cat  club_id  big_club  \
# name
# Alexis Sanchez              Chile            0        4        1         1
# Mesut Ozil                Germany            0        4        1         1
# Petr Cech          Czech Republic            0        6        1         1
# Theo Walcott              England            0        4        1         1
# Laurent Koscielny          France            0        4        1         1
#
#                    new_signing
# name
# Alexis Sanchez               0
# Mesut Ozil                   0
# Petr Cech                    0
# Theo Walcott                 0
# Laurent Koscielny            0

# %%
players_lite = players.iloc[:4,:4]

# %%
players_lite
# Out:
#                    club  age position  position_cat
# name
# Alexis Sanchez  Arsenal   28       LW             1
# Mesut Ozil      Arsenal   28       AM             1
# Petr Cech       Arsenal   35       GK             4
# Theo Walcott    Arsenal   28       RW             1

# %%
#players.reindex(index=[2,1,3,0],columns=['age','name','positon','club'])

# %%
#players.sort_values(by='market_value',ascending = False)

# %%
players.head()
# Out:
#                       club  age position  position_cat  market_value  \
# name
# Alexis Sanchez     Arsenal   28       LW             1          65.0
# Mesut Ozil         Arsenal   28       AM             1          50.0
# Petr Cech          Arsenal   35       GK             4           7.0
# Theo Walcott       Arsenal   28       RW             1          20.0
# Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#                    page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Alexis Sanchez           4329       12.0  17.10%         264       3
# Mesut Ozil               4395        9.5   5.60%         167       2
# Petr Cech                1529        5.5   5.90%         134       2
# Theo Walcott             2393        7.5   1.50%         122       1
# Laurent Koscielny         912        6.0   0.70%         121       2
#
#                       nationality  new_foreign  age_cat  club_id  big_club  \
# name
# Alexis Sanchez              Chile            0        4        1         1
# Mesut Ozil                Germany            0        4        1         1
# Petr Cech          Czech Republic            0        6        1         1
# Theo Walcott              England            0        4        1         1
# Laurent Koscielny          France            0        4        1         1
#
#                    new_signing
# name
# Alexis Sanchez               0
# Mesut Ozil                   0
# Petr Cech                    0
# Theo Walcott                 0
# Laurent Koscielny            0

# %%
players.sort_values(by='age',ascending = True)
# Out:
#                                      club  age position  position_cat  \
# name
# Ben Woodburn                    Liverpool   17       LW             1
# Josh Tymon                     Stoke+City   18       LB             3
# Jonathan Leko                   West+Brom   18       RW             1
# Trent Alexander-Arnold          Liverpool   18       RB             3
# Marcus Rashford         Manchester+United   19       CF             1
# ...                                   ...  ...      ...           ...
# Peter Crouch                   Stoke+City   36       CF             1
# Gareth Barry                      Everton   36       DM             2
# Artur Boruc                   Bournemouth   37       GK             4
# Gareth McAuley                  West+Brom   37       CB             3
# Julian Speroni             Crystal+Palace   38       GK             4
#
#                         market_value  page_views  fpl_value fpl_sel  \
# name
# Ben Woodburn                    1.50        1241        4.5   0.10%
# Josh Tymon                      1.00         120        4.5   0.10%
# Jonathan Leko                   1.50         169        4.5   0.20%
# Trent Alexander-Arnold          1.50         327        4.5   0.30%
# Marcus Rashford                18.00        3668        7.5   4.80%
# ...                              ...         ...        ...     ...
# Peter Crouch                    1.50        2656        5.0   2.90%
# Gareth Barry                    1.50        1331        4.5   1.70%
# Artur Boruc                     1.00         436        4.5   6.90%
# Gareth McAuley                  1.00         458        5.0  11.80%
# Julian Speroni                  0.25         188        4.0   2.00%
#
#                         fpl_points  region       nationality  new_foreign  \
# name
# Ben Woodburn                     5       1             Wales            0
# Josh Tymon                       9       1           England            0
# Jonathan Leko                   12       1           England            0
# Trent Alexander-Arnold          15       2           England            0
# Marcus Rashford                 76       1           England            0
# ...                            ...     ...               ...          ...
# Peter Crouch                    79       1           England            0
# Gareth Barry                    68       1           England            0
# Artur Boruc                    120       2            Poland            0
# Gareth McAuley                 131       2  Northern Ireland            0
# Julian Speroni                   0       3         Argentina            0
#
#                         age_cat  club_id  big_club  new_signing
# name
# Ben Woodburn                  1       10         1            0
# Josh Tymon                    1       15         0            0
# Jonathan Leko                 1       19         0            0
# Trent Alexander-Arnold        1       10         1            0
# Marcus Rashford               1       12         1            0
# ...                         ...      ...       ...          ...
# Peter Crouch                  6       15         0            0
# Gareth Barry                  6        7         0            0
# Artur Boruc                   6        2         0            0
# Gareth McAuley                6       19         0            0
# Julian Speroni                6        6         0            0
#
# [465 rows x 16 columns]

# %%
players.sort_values(by='age',ascending = True)
# Out:
#                                      club  age position  position_cat  \
# name
# Ben Woodburn                    Liverpool   17       LW             1
# Josh Tymon                     Stoke+City   18       LB             3
# Jonathan Leko                   West+Brom   18       RW             1
# Trent Alexander-Arnold          Liverpool   18       RB             3
# Marcus Rashford         Manchester+United   19       CF             1
# ...                                   ...  ...      ...           ...
# Peter Crouch                   Stoke+City   36       CF             1
# Gareth Barry                      Everton   36       DM             2
# Artur Boruc                   Bournemouth   37       GK             4
# Gareth McAuley                  West+Brom   37       CB             3
# Julian Speroni             Crystal+Palace   38       GK             4
#
#                         market_value  page_views  fpl_value fpl_sel  \
# name
# Ben Woodburn                    1.50        1241        4.5   0.10%
# Josh Tymon                      1.00         120        4.5   0.10%
# Jonathan Leko                   1.50         169        4.5   0.20%
# Trent Alexander-Arnold          1.50         327        4.5   0.30%
# Marcus Rashford                18.00        3668        7.5   4.80%
# ...                              ...         ...        ...     ...
# Peter Crouch                    1.50        2656        5.0   2.90%
# Gareth Barry                    1.50        1331        4.5   1.70%
# Artur Boruc                     1.00         436        4.5   6.90%
# Gareth McAuley                  1.00         458        5.0  11.80%
# Julian Speroni                  0.25         188        4.0   2.00%
#
#                         fpl_points  region       nationality  new_foreign  \
# name
# Ben Woodburn                     5       1             Wales            0
# Josh Tymon                       9       1           England            0
# Jonathan Leko                   12       1           England            0
# Trent Alexander-Arnold          15       2           England            0
# Marcus Rashford                 76       1           England            0
# ...                            ...     ...               ...          ...
# Peter Crouch                    79       1           England            0
# Gareth Barry                    68       1           England            0
# Artur Boruc                    120       2            Poland            0
# Gareth McAuley                 131       2  Northern Ireland            0
# Julian Speroni                   0       3         Argentina            0
#
#                         age_cat  club_id  big_club  new_signing
# name
# Ben Woodburn                  1       10         1            0
# Josh Tymon                    1       15         0            0
# Jonathan Leko                 1       19         0            0
# Trent Alexander-Arnold        1       10         1            0
# Marcus Rashford               1       12         1            0
# ...                         ...      ...       ...          ...
# Peter Crouch                  6       15         0            0
# Gareth Barry                  6        7         0            0
# Artur Boruc                   6        2         0            0
# Gareth McAuley                6       19         0            0
# Julian Speroni                6        6         0            0
#
# [465 rows x 16 columns]

# %%
players.set_index('club').sort_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-0fea410136d0> in <module>
# ----> 1 players.set_index('club').sort_index(inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['club'] are in the columns"

# %%
players.sort_values(by=['age','market_value'],ascending = [True,False])
# Out:
#                    age position  position_cat  market_value  page_views  \
# club
# Liverpool           17       LW             1          1.50        1241
# Liverpool           18       RB             3          1.50         327
# West+Brom           18       RW             1          1.50         169
# Stoke+City          18       LB             3          1.00         120
# Manchester+United   19       CF             1         18.00        3668
# ...                ...      ...           ...           ...         ...
# Watford             36       GK             4          1.00         439
# Brighton+and+Hove   36       RB             1          0.50         215
# Bournemouth         37       GK             4          1.00         436
# West+Brom           37       CB             3          1.00         458
# Crystal+Palace      38       GK             4          0.25         188
#
#                    fpl_value fpl_sel  fpl_points  region       nationality  \
# club
# Liverpool                4.5   0.10%           5       1             Wales
# Liverpool                4.5   0.30%          15       2           England
# West+Brom                4.5   0.20%          12       1           England
# Stoke+City               4.5   0.10%           9       1           England
# Manchester+United        7.5   4.80%          76       1           England
# ...                      ...     ...         ...     ...               ...
# Watford                  4.5   2.20%         113       3            Brazil
# Brighton+and+Hove        4.5   0.40%           0       3         Argentina
# Bournemouth              4.5   6.90%         120       2            Poland
# West+Brom                5.0  11.80%         131       2  Northern Ireland
# Crystal+Palace           4.0   2.00%           0       3         Argentina
#
#                    new_foreign  age_cat  club_id  big_club  new_signing
# club
# Liverpool                    0        1       10         1            0
# Liverpool                    0        1       10         1            0
# West+Brom                    0        1       19         0            0
# Stoke+City                   0        1       15         0            0
# Manchester+United            0        1       12         1            0
# ...                        ...      ...      ...       ...          ...
# Watford                      0        6       18         0            0
# Brighton+and+Hove            0        6        3         0            0
# Bournemouth                  0        6        2         0            0
# West+Brom                    0        6       19         0            0
# Crystal+Palace               0        6        6         0            0
#
# [465 rows x 15 columns]

# %%
#players.iloc[players.age.idxmin()]

# %%
players.head()
# Out:
#          age position  position_cat  market_value  page_views  fpl_value  \
# club
# Arsenal   28       LW             1          65.0        4329       12.0
# Arsenal   28       AM             1          50.0        4395        9.5
# Arsenal   35       GK             4           7.0        1529        5.5
# Arsenal   28       RW             1          20.0        2393        7.5
# Arsenal   31       CB             3          22.0         912        6.0
#
#         fpl_sel  fpl_points  region     nationality  new_foreign  age_cat  \
# club
# Arsenal  17.10%         264       3           Chile            0        4
# Arsenal   5.60%         167       2         Germany            0        4
# Arsenal   5.90%         134       2  Czech Republic            0        6
# Arsenal   1.50%         122       1         England            0        4
# Arsenal   0.70%         121       2          France            0        4
#
#          club_id  big_club  new_signing
# club
# Arsenal        1         1            0
# Arsenal        1         1            0
# Arsenal        1         1            0
# Arsenal        1         1            0
# Arsenal        1         1            0

# %%
players.duplicated()
# Out:
# club
# Arsenal     False
# Arsenal     False
# Arsenal     False
# Arsenal     False
# Arsenal     False
#             ...
# West+Ham    False
# West+Ham    False
# West+Ham    False
# West+Ham    False
# West+Ham    False
# Length: 465, dtype: bool

# %%
players[players.duplicated()]
# Out:
#          age position  position_cat  market_value  page_views  fpl_value  \
# club
# Arsenal   24       DM             2          35.0        1815        5.5
# Arsenal   23       RM             2          22.0        1519        6.0
# Arsenal   23       RM             2          22.0        1519        6.0
#
#         fpl_sel  fpl_points  region  nationality  new_foreign  age_cat  \
# club
# Arsenal   2.00%          85       2  Switzerland            0        2
# Arsenal   1.80%          83       1      England            0        2
# Arsenal   1.80%          83       1      England            0        2
#
#          club_id  big_club  new_signing
# club
# Arsenal        1         1            0
# Arsenal        1         1            0
# Arsenal        1         1            0

# %%
players.loc[players.duplicated(subset=['club','age','position','market_value'])].shape
# Out:
# (7, 17)

# %%
players.loc[players.duplicated(subset=['club','age','position','market_value'],keep='last')].shape
# Out:
# (7, 17)

# %%
players.loc[players.duplicated(subset=['club','age','position','market_value'],keep=False)].shape
# Out:
# (13, 17)

# %%
players[players.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
players.market_value.mean()
# Out:
# 11.125649350649349

# %%
players.drop_duplicates(keep='first')
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0          4329       12.0  17.10%         264       3           Chile
# 1          4395        9.5   5.60%         167       2         Germany
# 2          1529        5.5   5.90%         134       2  Czech Republic
# 3          2393        7.5   1.50%         122       1         England
# 4           912        6.0   0.70%         121       2          France
# ..          ...        ...     ...         ...     ...             ...
# 460         288        4.5   0.40%          38       2     Switzerland
# 461         199        4.5   0.20%          34       4        Congo DR
# 462         198        4.5   0.30%          29       1         England
# 463         412        4.5   5.90%          16       1         England
# 464         214        5.5   0.10%          12       4         Senegal
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 0              0        4        1         1            0
# 1              0        4        1         1            0
# 2              0        6        1         1            0
# 3              0        4        1         1            0
# 4              0        4        1         1            0
# ..           ...      ...      ...       ...          ...
# 460            0        1       20         0            1
# 461            0        2       20         0            1
# 462            0        2       20         0            0
# 463            0        1       20         0            1
# 464            0        3       20         0            0
#
# [462 rows x 17 columns]

# %%
players.drop_duplicates(keep='first').market_value.mean()
# Out:
# 11.026252723311545

# %%
players[players.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
players.columns
# Out:
# Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')

# %%
players.drop(labels=['age','market_value'], axis='columns')
# Out:
#                     name      club position  position_cat  page_views  \
# 0         Alexis Sanchez   Arsenal       LW             1        4329
# 1             Mesut Ozil   Arsenal       AM             1        4395
# 2              Petr Cech   Arsenal       GK             4        1529
# 3           Theo Walcott   Arsenal       RW             1        2393
# 4      Laurent Koscielny   Arsenal       CB             3         912
# ..                   ...       ...      ...           ...         ...
# 460  Edimilson Fernandes  West+Ham       CM             2         288
# 461       Arthur Masuaku  West+Ham       LB             3         199
# 462            Sam Byram  West+Ham       RB             3         198
# 463      Ashley Fletcher  West+Ham       CF             1         412
# 464         Diafra Sakho  West+Ham       CF             1         214
#
#      fpl_value fpl_sel  fpl_points  region     nationality  new_foreign  \
# 0         12.0  17.10%         264       3           Chile            0
# 1          9.5   5.60%         167       2         Germany            0
# 2          5.5   5.90%         134       2  Czech Republic            0
# 3          7.5   1.50%         122       1         England            0
# 4          6.0   0.70%         121       2          France            0
# ..         ...     ...         ...     ...             ...          ...
# 460        4.5   0.40%          38       2     Switzerland            0
# 461        4.5   0.20%          34       4        Congo DR            0
# 462        4.5   0.30%          29       1         England            0
# 463        4.5   5.90%          16       1         England            0
# 464        5.5   0.10%          12       4         Senegal            0
#
#      age_cat  club_id  big_club  new_signing
# 0          4        1         1            0
# 1          4        1         1            0
# 2          6        1         1            0
# 3          4        1         1            0
# 4          4        1         1            0
# ..       ...      ...       ...          ...
# 460        1       20         0            1
# 461        2       20         0            1
# 462        2       20         0            0
# 463        1       20         0            1
# 464        3       20         0            0
#
# [465 rows x 15 columns]

# %%
players.drop(columns=['age','market_value'])
# Out:
#                     name      club position  position_cat  page_views  \
# 0         Alexis Sanchez   Arsenal       LW             1        4329
# 1             Mesut Ozil   Arsenal       AM             1        4395
# 2              Petr Cech   Arsenal       GK             4        1529
# 3           Theo Walcott   Arsenal       RW             1        2393
# 4      Laurent Koscielny   Arsenal       CB             3         912
# ..                   ...       ...      ...           ...         ...
# 460  Edimilson Fernandes  West+Ham       CM             2         288
# 461       Arthur Masuaku  West+Ham       LB             3         199
# 462            Sam Byram  West+Ham       RB             3         198
# 463      Ashley Fletcher  West+Ham       CF             1         412
# 464         Diafra Sakho  West+Ham       CF             1         214
#
#      fpl_value fpl_sel  fpl_points  region     nationality  new_foreign  \
# 0         12.0  17.10%         264       3           Chile            0
# 1          9.5   5.60%         167       2         Germany            0
# 2          5.5   5.90%         134       2  Czech Republic            0
# 3          7.5   1.50%         122       1         England            0
# 4          6.0   0.70%         121       2          France            0
# ..         ...     ...         ...     ...             ...          ...
# 460        4.5   0.40%          38       2     Switzerland            0
# 461        4.5   0.20%          34       4        Congo DR            0
# 462        4.5   0.30%          29       1         England            0
# 463        4.5   5.90%          16       1         England            0
# 464        5.5   0.10%          12       4         Senegal            0
#
#      age_cat  club_id  big_club  new_signing
# 0          4        1         1            0
# 1          4        1         1            0
# 2          6        1         1            0
# 3          4        1         1            0
# 4          4        1         1            0
# ..       ...      ...       ...          ...
# 460        1       20         0            1
# 461        2       20         0            1
# 462        2       20         0            0
# 463        1       20         0            1
# 464        3       20         0            0
#
# [465 rows x 15 columns]

# %%
players.pop('club')
# Out:
# 0       Arsenal
# 1       Arsenal
# 2       Arsenal
# 3       Arsenal
# 4       Arsenal
#          ...
# 460    West+Ham
# 461    West+Ham
# 462    West+Ham
# 463    West+Ham
# 464    West+Ham
# Name: club, Length: 465, dtype: object

# %%
players.pop('club','age')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-265304cb43da> in <module>
# ----> 1 players.pop('club','age')
#
# TypeError: pop() takes 2 positional arguments but 3 were given

# %%
players.pop('age')
# Out:
# 0      28
# 1      28
# 2      35
# 3      28
# 4      31
#        ..
# 460    21
# 461    23
# 462    23
# 463    21
# 464    27
# Name: age, Length: 465, dtype: int64

# %%
players.reindex(index=[0,3,9])
# Out:
#              name position  position_cat  market_value  page_views  fpl_value  \
# 0  Alexis Sanchez       LW             1          65.0        4329       12.0
# 3    Theo Walcott       RW             1          20.0        2393        7.5
# 9      Alex Iwobi       LW             1          10.0        1812        5.5
#
#   fpl_sel  fpl_points  region nationality  new_foreign  age_cat  club_id  \
# 0  17.10%         264       3       Chile            0        4        1
# 3   1.50%         122       1     England            0        4        1
# 9   1.00%          89       4     Nigeria            0        1        1
#
#    big_club  new_signing
# 0         1            0
# 3         1            0
# 9         1            0

# %%
players.shape
# Out:
# (465, 17)

# %%
type(players.age)
# Out:
# pandas.core.series.Series

# %%
ages = players.age

# %%
ages.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
ages[ages.isna()]
# Out:
# Series([], Name: age, dtype: int64)

# %%
players.isna()
# Out:
#       name   club    age  position  position_cat  market_value  page_views  \
# 0    False  False  False     False         False         False       False
# 1    False  False  False     False         False         False       False
# 2    False  False  False     False         False         False       False
# 3    False  False  False     False         False         False       False
# 4    False  False  False     False         False         False       False
# ..     ...    ...    ...       ...           ...           ...         ...
# 460  False  False  False     False         False         False       False
# 461  False  False  False     False         False         False       False
# 462  False  False  False     False         False         False       False
# 463  False  False  False     False         False         False       False
# 464  False  False  False     False         False         False       False
#
#      fpl_value  fpl_sel  fpl_points  region  nationality  new_foreign  \
# 0        False    False       False   False        False        False
# 1        False    False       False   False        False        False
# 2        False    False       False   False        False        False
# 3        False    False       False   False        False        False
# 4        False    False       False   False        False        False
# ..         ...      ...         ...     ...          ...          ...
# 460      False    False       False   False        False        False
# 461      False    False       False   False        False        False
# 462      False    False       False   False        False        False
# 463      False    False       False   False        False        False
# 464      False    False       False   False        False        False
#
#      age_cat  club_id  big_club  new_signing
# 0      False    False     False        False
# 1      False    False     False        False
# 2      False    False     False        False
# 3      False    False     False        False
# 4      False    False     False        False
# ..       ...      ...       ...          ...
# 460    False    False     False        False
# 461    False    False     False        False
# 462    False    False     False        False
# 463    False    False     False        False
# 464    False    False     False        False
#
# [465 rows x 17 columns]

# %%
np.count_nonzero(players.isna())
# Out:
# 4

# %%
players[players.isna()]
# Out:
#     name club  age position  position_cat  market_value  page_views  \
# 0    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 1    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 2    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 3    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 4    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# ..   ...  ...  ...      ...           ...           ...         ...
# 460  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 461  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 462  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 463  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 464  NaN  NaN  NaN      NaN           NaN           NaN         NaN
#
#      fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# 0          NaN     NaN         NaN     NaN         NaN          NaN      NaN
# 1          NaN     NaN         NaN     NaN         NaN          NaN      NaN
# 2          NaN     NaN         NaN     NaN         NaN          NaN      NaN
# 3          NaN     NaN         NaN     NaN         NaN          NaN      NaN
# 4          NaN     NaN         NaN     NaN         NaN          NaN      NaN
# ..         ...     ...         ...     ...         ...          ...      ...
# 460        NaN     NaN         NaN     NaN         NaN          NaN      NaN
# 461        NaN     NaN         NaN     NaN         NaN          NaN      NaN
# 462        NaN     NaN         NaN     NaN         NaN          NaN      NaN
# 463        NaN     NaN         NaN     NaN         NaN          NaN      NaN
# 464        NaN     NaN         NaN     NaN         NaN          NaN      NaN
#
#      club_id  big_club  new_signing
# 0        NaN       NaN          NaN
# 1        NaN       NaN          NaN
# 2        NaN       NaN          NaN
# 3        NaN       NaN          NaN
# 4        NaN       NaN          NaN
# ..       ...       ...          ...
# 460      NaN       NaN          NaN
# 461      NaN       NaN          NaN
# 462      NaN       NaN          NaN
# 463      NaN       NaN          NaN
# 464      NaN       NaN          NaN
#
# [465 rows x 17 columns]

# %%
players[players.isna().values]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players[players.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.fillna('some meaningful replacement value').loc[[30,192,195]]
# Out:
#                   name            club  age  \
# 30        Granit Xhaka         Arsenal   24
# 192       Steve Mounie    Huddersfield   22
# 195  Kasper Schmeichel  Leicester+City   30
#
#                               position  position_cat  \
# 30   some meaningful replacement value             2
# 192                                 CF             1
# 195                                 GK             4
#
#                           market_value  page_views  fpl_value fpl_sel  \
# 30   some meaningful replacement value        1815        5.5   2.00%
# 192  some meaningful replacement value          56        6.0   0.60%
# 195  some meaningful replacement value        1601        5.0   2.40%
#
#      fpl_points  region  nationality  new_foreign  age_cat  club_id  big_club  \
# 30           85       2  Switzerland            0        2        1         1
# 192           0       2        Benin            0        2        8         0
# 195         109       2      Denmark            0        4        9         0
#
#      new_signing
# 30             0
# 192            0
# 195            0

# %%
players.fillna({
    'market_value':100,
    'position': 'RM'
}).loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       RM             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30          100.0        1815        5.5   2.00%          85       2
# 192         100.0          56        6.0   0.60%           0       2
# 195         100.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players.fillna({
    'market_value':players.market_value.mean(),
    'position': 'RM'
}).loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       RM             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30      11.125649        1815        5.5   2.00%          85       2
# 192     11.125649          56        6.0   0.60%           0       2
# 195     11.125649        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.dropna(axis=0, how='all').loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.head(3)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
# 2       Petr Cech  Arsenal   35       GK             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0

# %%
df2 = players.drop(labels=[2,10,21],axis=0)\
  .drop(labels='market_value',axis=1)

# %%
df2 = players.drop(index=[2,10,21],columns = 'market_value')

# %%
df2.nationality.isnull().sum()
# Out:
# 0

# %%
df2.nationality[df2.nationality.isnull()]
# Out:
# Series([], Name: nationality, dtype: object)

# %%
df2.nationality.drop_duplicates().size
# Out:
# 61

# %%
df2.nationality.nunique()
# Out:
# 61

# %%
df2.drop_duplicates(subset=['age','club','position'],keep = 'first').loc[:,['age','position']]
# Out:
#      age position
# 0     28       LW
# 1     28       AM
# 3     28       RW
# 4     31       CB
# 5     22       RB
# ..   ...      ...
# 460   21       CM
# 461   23       LB
# 462   23       RB
# 463   21       CF
# 464   27       CF
#
# [433 rows x 2 columns]

# %%
players.agg('mean')
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.new_signing.mean()
# Out:
# 0.14408602150537633

# %%
players.agg(np.min)
# Out:
# name            Aaron Cresswell
# club                    Arsenal
# age                          17
# position_cat                  1
# market_value               0.05
# page_views                    3
# fpl_value                     4
# fpl_sel                   0.00%
# fpl_points                    0
# region                        1
# nationality             Algeria
# new_foreign                   0
# age_cat                       1
# club_id                       1
# big_club                      0
# new_signing                   0
# dtype: object

# %%
'a' > 'b'
# Out:
# False

# %%
ord('a')
# Out:
# 97

# %%
ord('b')
# Out:
# 98

# %%
players.head(3)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
# 2       Petr Cech  Arsenal   35       GK             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0

# %%
players.loc[:,['market_value','fpl_value']].transform(lambda x: x*0.91)
# Out:
#      market_value  fpl_value
# 0          59.150     10.920
# 1          45.500      8.645
# 2           6.370      5.005
# 3          18.200      6.825
# 4          20.020      5.460
# ..            ...        ...
# 460         4.550      4.095
# 461         6.370      4.095
# 462         4.095      4.095
# 463         0.910      4.095
# 464         9.100      5.005
#
# [465 rows x 2 columns]

# %%
players.loc[:,['market_value','fpl_value']]*0.91
# Out:
#      market_value  fpl_value
# 0          59.150     10.920
# 1          45.500      8.645
# 2           6.370      5.005
# 3          18.200      6.825
# 4          20.020      5.460
# ..            ...        ...
# 460         4.550      4.095
# 461         6.370      4.095
# 462         4.095      4.095
# 463         0.910      4.095
# 464         9.100      5.005
#
# [465 rows x 2 columns]

# %%
from random import choice

# %%
names = ['Bud','Brooke','Paleo']

# %%
choice(names)
# Out:
# 'Paleo'

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.loc[0:3, 'position'] = ['CM','RW','CB','GK']

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       CM             1          65.0
# 1         Mesut Ozil  Arsenal   28       RW             1          50.0
# 2          Petr Cech  Arsenal   35       CB             4           7.0
# 3       Theo Walcott  Arsenal   28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.loc[players.name.str.startswith('Aaron')]
# Out:
#                 name          club  age position  position_cat  market_value  \
# 15      Aaron Ramsey       Arsenal   26       CM             2          35.0
# 157     Aaron Lennon       Everton   30       RW             1           5.0
# 176       Aaron Mooy  Huddersfield   26       CM             2           5.0
# 455  Aaron Cresswell      West+Ham   27       LB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 15         1040        7.0   5.10%          56       1       Wales
# 157         504        5.5   0.20%          22       1     England
# 176         588        5.5   2.50%           0       4   Australia
# 455         380        5.0   1.30%          60       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 15             0        3        1         1            0
# 157            0        4        7         0            0
# 176            0        3        8         0            0
# 455            0        3       20         0            0

# %%
players.loc[[15,157,176,455]]
# Out:
#                 name          club  age position  position_cat  market_value  \
# 15      Aaron Ramsey       Arsenal   26       CM             2          35.0
# 157     Aaron Lennon       Everton   30       RW             1           5.0
# 176       Aaron Mooy  Huddersfield   26       CM             2           5.0
# 455  Aaron Cresswell      West+Ham   27       LB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 15         1040        7.0   5.10%          56       1       Wales
# 157         504        5.5   0.20%          22       1     England
# 176         588        5.5   2.50%           0       4   Australia
# 455         380        5.0   1.30%          60       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 15             0        3        1         1            0
# 157            0        4        7         0            0
# 176            0        3        8         0            0
# 455            0        3       20         0            0

# %%
players['age'].iloc[1] = '12'
# Out:
# C:\Users\shaoni biswas\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
